# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
expression_data = {
    "ENSG00000141510": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55
    },
    "ENSG00000012048": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4
    },
    "ENSG00000139618": {
        "gene_name": "BRCA2",
        "sample1": 100,
        "sample2": 120,
        "sample3": 110
    },
    "ENSG00000210082": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0
    }
}


'''🎯 任务：
请使用 for 循环，完成以下操作：
for gene_id,info in expression_data.items():
遍历 expression_data 中的每个基因。
gene_id = info["gene_name"]
对每个基因的样本表达量进行筛选，只保留表达量大于 50 的样本名。
sample ={}
if k,v in info.items():
    if k.startswith("sample") and v >50:
        sample[k] = v
        
构造一个新的字典 report，以 "gene_name" 为键，以符合条件的样本名列表为值。

如果某个基因没有任何样本表达量大于 50，则不包含在 report 中
'''
report ={}
for gene_id,info in expression_data.items():
    gene_name = info["gene_name"]
    sample ={}
    for k,v in info.items():
        if k.startswith("sample") and v >50 :
            sample[k] = v
        if sample:
            report[gene_name] = sample
report
# Out:
# {'TP53': {'sample2': 60, 'sample3': 55},
#  'BRCA2': {'sample1': 100, 'sample2': 120, 'sample3': 110}}

# %%
# 🎯 任务一：写入新字典 avg_report
# ✅ 要求：
# 使用 for 循环遍历每个基因

# 计算该基因所有样本的平均表达量（不包括 "gene_name"）

# 构造一个新字典 avg_report，以 "gene_name" 为键，平均表达量为值



expression_data = {
    "ENSG00000141510": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55
    },
    "ENSG00000012048": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4
    },
    "ENSG00000139618": {
        "gene_name": "BRCA2",
        "sample1": 100,
        "sample2": 120,
        "sample3": 110
    },
    "ENSG00000210082": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0
    }
}

import pandas as pd
# df = pd.DataFrame(expression_data).T
# df
# df['ave_expression'] = df.drop(columns='gene_name').mean(axis=1)

avg_report = {}
for gene_id ,info in expression_data.items():
    gene_name = info["gene_name"]
    sample_values = []
    for k,v in info.items():
        if k != "gene_name":
            sample_values.append(v)
    mean = sum(sample_values)/len(sample_values)
    avg_report[gene_name] = round(mean,3)
avg_report
# Out:
# {'TP53': 55.0, 'BRCA1': 4.0, 'BRCA2': 110.0, 'MIR21': 0.333}

# %%
expression_data = {
    "ENSG00000141510": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55
    },
    "ENSG00000012048": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4
    },
    "ENSG00000139618": {
        "gene_name": "BRCA2",
        "sample1": 100,
        "sample2": 120,
        "sample3": 110
    },
    "ENSG00000210082": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0
    }
}


'''🎯 任务：
请使用 for 循环，完成以下操作：

遍历 expression_data 中的每个基因。

对每个基因的样本表达量进行筛选，只保留表达量大于 50 的样本名。

构造一个新的字典 report，以 "gene_name" 为键，以符合条件的样本名列表为值。

如果某个基因没有任何样本表达量大于 50，则不包含在 report 中
'''

'''
report ={"gene_name(TP53)":{"sample1":50,"sample2":60,"sample3":55},
         "gene_name(BRCA2)":{"sample1":100,"sample2":120,"sample3":110}}

'''
report ={}
for gene_id,info in expression_data.items():
    gene_name = info["gene_name"]
    expr = {}
    for k,v in info.items():
        if k != "gene_name" and  v >50:
            expr[k] = v
        if expr:   # 只有在有符合条件的样本时才加入
            report[f'gene_name({gene_name})'] = expr
report       

# df = pd.DataFrame(expression_data).T
# df.set_index('gene_name',inplace = True)
# # 提取每行中表达值 ≥ 50 的样本和值，返回字典
# filtered_rows = df.apply(lambda row: {col: val for col, val in row.items() if val >= 50}, axis=1)

# # 转换为新的 DataFrame
# df_filtered = pd.DataFrame(filtered_rows.tolist(), index=filtered_rows.index)
# df_filtered_clean = df_filtered.dropna(how='all')  # 去掉全是NaN的行
# df_filtered_clean
# Out:
# {'gene_name(TP53)': {'sample2': 60, 'sample3': 55},
#  'gene_name(BRCA2)': {'sample1': 100, 'sample2': 120, 'sample3': 110}}

# %%
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 40,
        "sample5": 30,
        "sample6": 70
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4,
        "sample4": 6,
        "sample5": 2,
        "sample6": 8
    }
}
'''
🧠 题目：筛选高表达样本并统计每个基因的表达偏移
🎯 目标：
给定如下结构的表达数据字典，每个基因包含：

"gene_name"：基因名称

"sample1" 至 "sample6"：6 个样本的表达值

请你用 for 循环完成以下任务：

遍历每个基因的表达值

计算该基因的表达均值（组内均值）

找出高于均值的样本名和表达值，存入 "high_samples" 字典

找出低于均值的样本名和表达值，存入 "low_samples" 字典

计算高表达组和低表达组的均值

计算两组均值的差值（表达偏移）

把这些结果存入一个新字典 expression_shift，结构如下：

expression_shift = {
    "TP53": {
        "group_mean": 55.0,
        "high_samples": {"sample2": 60, "sample3": 55},
        "low_samples": {"sample1": 50},
        "high_mean": 57.5,
        "low_mean": 50.0,
        "shift": 7.5
    },
    ...
}


'''
# Out:
# '\n🧠 题目：筛选高表达样本并统计每个基因的表达偏移\n🎯 目标：\n给定如下结构的表达数据字典，每个基因包含：\n\n"gene_name"：基因名称\n\n"sample1" 至 "sample6"：6 个样本的表达值\n\n请你用 for 循环完成以下任务：\n\n遍历每个基因的表达值\n\n计算该基因的表达均值（组内均值）\n\n找出高于均值的样本名和表达值，存入 "high_samples" 字典\n\n找出低于均值的样本名和表达值，存入 "low_samples" 字典\n\n计算高表达组和低表达组的均值\n\n计算两组均值的差值（表达偏移）\n\n把这些结果存入一个新字典 expression_shift，结构如下：\n\nexpression_shift = {\n    "TP53": {\n        "group_mean": 55.0,\n        "high_samples": {"sample2": 60, "sample3": 55},\n        "low_samples": {"sample1": 50},\n        "high_mean": 57.5,\n        "low_mean": 50.0,\n        "shift": 7.5\n    },\n    ...\n}\n\n\n'

# %%
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 40,
        "sample5": 30,
        "sample6": 70
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4,
        "sample4": 6,
        "sample5": 2,
        "sample6": 8
    }
}
for gene_name,info in expression_data.items():
    gene_name = info["gene_name"]
    samples = []
    
    for k,v in info.items():
       if k.startswith("sample"):
        samples.append (v)

    mean = sum(samples)/len(samples)
    high_samples ={}
    low_samples ={}
    for k,v in info.items():
        if k.startswith("sample"):
            if v > mean:
                high_samples[k] = v
            else:
                low_samples[k] = v

high_samples
high_values =[]
for k,v in high_samples.items():
    high_values.append(v)

high_mean = sum(high_values)/len(high_values)
    
low_samples
low_values =[]
for k,v in low_samples.items():
    low_values.append(v)

low_mean = sum(low_values)/len(low_values)

# %%
🎯 挑战练习：一步一步来
现在，让我们一起只关注一个核心步骤：计算高表达组的平均值 (high_mean)。

请根据我们之前代码中的变量，尝试完成以下代码块。

前提条件 (假设以下变量已存在):

high_group_values: 一个列表，里面存储了所有高于均值的表达值。

high_mean: 目标变量，用来存储计算出的高表达组平均值。

Python

# 假设这是 high_group_values 的示例
# high_group_values = [60, 55, 70] 

# 计算高表达组均值
if high_group_values:
    # 你的代码块，计算 high_mean
    # 提示：均值 = 总和 / 数量
    
    # high_mean = ???
    
else:
    high_mean = "N/A"

# 请尝试只填写上面的 ??? 部分
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 40,
        "sample5": 30,
        "sample6": 70
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4,
        "sample4": 6,
        "sample5": 2,
        "sample6": 8
    }
}
# Out:
#   Cell In[7], line 1
#     🎯 挑战练习：一步一步来
#     ^
# SyntaxError: invalid character '🎯' (U+1F3AF)

# %% [markdown]
# 当然可以！给你一个清晰的中文伪代码思路，让你能够按照步骤一步步地将复杂的逻辑翻译成 Python 代码。
#
# 我们将继续使用你之前的数据结构和要求。
#
# 中文伪代码思路（针对单个基因的报告生成）
# 目标： 计算每个基因的总体均值、高低表达组、高低组均值，以及均值差，并存入 expression_shift 字典。
#
# 预备工作：
# 定义 expression_data 字典（原始数据）。
#
# 初始化结果字典 expression_shift = {}。
#
# 第一步：循环并准备数据
# // 遍历 expression_data 中的每一个基因（键是 gene_id，值是 info）
# 开始 for 循环 (gene_id, info) 在 expression_data 中：
#
#     // 1. 初始化容器：准备一个列表来收集所有样本值
#     创建一个空列表：all_sample_values_list
#
#     // 2. 遍历当前基因 info 中的所有键值对 (k, v)
#     开始内部 for 循环 (k, v) 在 info 中：
#         如果 k 是以 "sample" 开头的（即是样本数据）：
#             将 v (表达值) 添加到 all_sample_values_list 中
#
#     // 3. 计算总体均值
#     如果 all_sample_values_list 不为空：
#         计算 all_sample_values_list 的总和 (sum)
#         计算 all_sample_values_list 的数量 (len)
#         计算总体均值 overall_mean = 总和 / 数量
#     否则:
#         overall_mean = 0 // 避免除以零错误
# 第二步：划分高低表达组
#     // 4. 初始化高低表达组的容器
#     创建一个空字典：high_samples_dict （存高于均值的样本名和值）
#     创建一个空字典：low_samples_dict （存低于或等于均值的样本名和值）
#
#     // 还需要两个列表来存值，方便下一步计算高低组均值
#     创建一个空列表：high_group_values_list
#     创建一个空列表：low_group_values_list
#
#     // 5. 再次遍历当前基因 info 中的所有键值对 (k, v)
#     开始内部 for 循环 (k, v) 在 info 中：
#         如果 k 是以 "sample" 开头的（即是样本数据）：
#
#             // 进行判断和分组
#             如果 v (表达值) > overall_mean：
#                 // 存入高表达组
#                 将 键 k 和 值 v 存入 high_samples_dict
#                 将 值 v 存入 high_group_values_list
#
#             否则 (v <= overall_mean)：
#                 // 存入低表达组
#                 将 键 k 和 值 v 存入 low_samples_dict
#                 将 值 v 存入 low_group_values_list
# 第三步：计算组均值和偏移
#     // 6. 计算高表达组的均值 (high_mean)
#     如果 high_group_values_list 不为空：
#         high_mean = sum(high_group_values_list) / len(high_group_values_list)
#     否则:
#         high_mean = "N/A"
#
#     // 7. 计算低表达组的均值 (low_mean)
#     如果 low_group_values_list 不为空：
#         low_mean = sum(low_group_values_list) / len(low_group_values_list)
#     否则:
#         low_mean = "N/A"
#
#     // 8. 计算组间偏移 (shift)
#     如果 high_mean 和 low_mean 都不是 "N/A"：
#         shift_value = high_mean - low_mean
#     否则:
#         shift_value = "N/A"
# 第四步：构建报告并存储
#     // 9. 构建当前基因的报告字典 (report)
#     创建一个新字典：report
#
#     // 存入计算结果 (可以四舍五入到小数点后4位，增加可读性)
#     report["overall_mean"] = 总体均值 overall_mean
#     report["high_samples"] = high_samples_dict
#     report["low_samples"] = low_samples_dict
#     report["high_mean"] = high_mean
#     report["low_mean"] = low_mean
#     report["shift"] = shift_value
#
#     // 10. 将报告存入最终结果字典
#     将 report 存入 expression_shift，键为 gene_id
#
# 结束 for 循环 (gene_id, info)
# 现在，请你尝试把这些中文步骤，一步一步地翻译成 Python 代码。 慢慢来，一次只关注一个步骤！

# %%
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 40,
        "sample5": 30,
        "sample6": 70
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4,
        "sample4": 6,
        "sample5": 2,
        "sample6": 8
    },
    "MIR21": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0,
        "sample4": 0,
        "sample5": 0,
        "sample6": 0
    }
}


'''
🧠 题目：统计每个基因的高表达样本数量，并筛选出高表达样本数 ≥ 3 的基因
🎯 目标：
给定如下结构的表达数据字典，每个基因包含多个样本表达值。请你用 for 循环完成以下任务：

遍历每个基因的表达值

计算该基因的表达均值（组内均值）

找出高于均值的样本名

统计高表达样本的数量

如果高表达样本数 ≥ 3，则把该基因加入新字典 selected_genes

'''
selected_genes = {}
for gene_id ,info in expression_data.items():
    values = []
    for k,v in info.items():
        if k != "gene_name":
            values.append(v)
    mean = sum(values)/len(values)

    high_samples ={}
    for k,v in info.items():
        if k !="gene_name" and v > mean:
            high_samples[k] = v
        
    if len(high_samples) >= 3:
        selected_genes[gene_id] = {
            "high_count": len(high_samples),
            "high_samples": list(high_samples.keys())
        }   
        
selected_genes

# %%
'''
🎯 目标：
给定如下结构的表达数据字典，每个基因包含多个样本表达值。请你用 for 循环完成以下任务：

遍历每个基因的表达值

计算该基因的表达均值（group_mean）

将表达值高于均值的样本归入 "high_group"，低于均值的归入 "low_group"

分别计算高表达组和低表达组的均值
 
计算组间差值（高表达均值 - 低表达均值）

如果差值 ≥ 10，则将该基因加入新字典 expression_report

新字典结构如下：
expression_report = {
    "TP53": {
        "group_mean": 50.83,
        "high_group": {"sample2"：60, "sample3"：55, "sample6"：70},
        "low_group": {"sample1"：50, "sample4"：40, "sample5"：30},
        "high_mean": 61.67,
        "low_mean": 40.00,
        "diff": 21.67
    },
    ...
}
'''
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 40,
        "sample5": 30,
        "sample6": 70
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4,
        "sample4": 6,
        "sample5": 2,
        "sample6": 8
    },
    "MIR21": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0,
        "sample4": 0,
        "sample5": 0,
        "sample6": 0
    }
}


'''
1,遍历键值对
for gene_id,info in expression_data.items():

2,设个装表达值的空列表 values = []

3,从info中取键值对
for k,v in info.items():

4，从sample键中取值
if k != "gene_name":
    values.append(v)

5.计算该基因的表达均值（group_mean）
group_mean = sum(values)/len(values)


6,用字典将每组的均值存起来，免得被覆盖
mean ={}
mean [group_mean_value] = group_mean

7,再次遍历info.items,取出其中的sample键值对，用sample的值和group_mean比较，


8，if v > group_mean，归入 high_group ，high_group[k] = v


9, if v<=group_mean,归入  low_group , low_group[k] = v


10, high =[]
    for values in high_group.values():
        high.append(values)
    high_mean = sum(high)/len(high)

11,low =[]
    for values in low_group.values():
        low.append(values)
    low_mean = sum(low)/len(low)


12,用字典存下每个基因的 high_mean 和 low_mean ,


13，diff = high_mean - low_mean

'''

# %% [markdown]
# expression_data = {
#     "TP53": {
#         "gene_name": "TP53",
#         "sample1": 50,
#         "sample2": 60,
#         "sample3": 55,
#         "sample4": 40,
#         "sample5": 30,
#         "sample6": 70
#     },
#     "BRCA1": {
#         "gene_name": "BRCA1",
#         "sample1": 5,
#         "sample2": 3,
#         "sample3": 4,
#         "sample4": 6,
#         "sample5": 2,
#         "sample6": 8
#     },
#     "MIR21": {
#         "gene_name": "MIR21",
#         "sample1": 0,
#         "sample2": 1,
#         "sample3": 0,
#         "sample4": 0,
#         "sample5": 0,
#         "sample6": 0
#     }
# }
#
# expression_report = {}
#
# for gene_id, info in expression_data.items():
#     # 1. 收集表达值
#     values = [v for k, v in info.items() if k.startswith("sample")]
#
#     # 2. 计算表达均值
#     group_mean = sum(values) / len(values)
#
#     # 3. 分组
#     high_group = {}
#     low_group = {}
#     for k, v in info.items():
#         if k.startswith("sample"):
#             if v > group_mean:
#                 high_group[k] = v
#             else:
#                 low_group[k] = v
#
#     # 4. 计算高表达组均值
#     high_values = list(high_group.values())
#     high_mean = sum(high_values) / len(high_values) if high_values else 0
#
#     # 5. 计算低表达组均值
#     low_values = list(low_group.values())
#     low_mean = sum(low_values) / len(low_values) if low_values else 0
#
#     # 6. 计算差值
#     diff = high_mean - low_mean
#
#     # 7. 满足条件则加入报告
#     if diff >= 10:
#         expression_report[gene_id] = {
#             "group_mean": round(group_mean, 2),
#             "high_group": high_group,
#             "low_group": low_group,
#             "high_mean": round(high_mean, 2),
#             "low_mean": round(low_mean, 2),
#             "diff": round(diff, 2)
#         }
#
# # 8. 打印结果
# for gene, report in expression_report.items():
#     print(f"\n基因 {gene} 的表达报告：")
#     for k, v in report.items():
#         print(f"  {k}: {v}")

# %%
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 40,
        "sample5": 30,
        "sample6": 70
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4,
        "sample4": 6,
        "sample5": 2,
        "sample6": 8
    },
    "MIR21": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0,
        "sample4": 0,
        "sample5": 0,
        "sample6": 0
    }
}




expression_report = {}
for gene ,info in expression_data.items():
    gene_name = info["gene_name"]
    
    values = []
    for k,v in info.items():
        if k != "gene_name":
            values.append(v)
    group_mean = sum(values)/len(values)
    high_group ={}
    low_group ={}
    for k,v in info.items():
        if k!= "gene_name" and v > group_mean:
            high_group[k] = v
        if k != "gene_name" and v <= group_mean :
            low_group[k] = v
    high = []
    low = []
    for values in high_group.values():
        high.append(values)
    for values in low_group.values():
        low.append(values)

    high_mean = sum(high)/len(high)
    low_mean = sum(low)/len(low)
    diff = high_mean - low_mean

# 假设你在前面的代码中已经成功计算出以下变量：
# gene_id (例如: "TP53")
# group_mean (例如: 50.833333333333336)
# high_group (例如: {'sample2': 60, 'sample3': 55, 'sample6': 70})
# low_group (例如: {'sample1': 50, 'sample4': 40, 'sample5': 30})
# high_mean (例如: 61.666666666666664)
# low_mean (例如: 40.0)
# diff (例如: 21.666666666666664)


    # ------------------------------------------------------------------
    #  在你最后的计算 (diff) 之后，立即添加以下代码块来保存结果：
    # ------------------------------------------------------------------
    
    # 1. 创建一个临时的报告字典，用于存储当前基因的所有信息
    current_gene_report = {
        # 总体信息
        "overall_mean": round(group_mean, 4), 
        
        # 分组结果
        "high_samples": high_group,
        "low_samples": low_group,
        
        # 组均值
        "high_mean": round(high_mean, 4),
        "low_mean": round(low_mean, 4),
        
        # 最终差值 (shift)
        "shift": round(diff, 4)
    }
    
    # 2. 将当前基因的报告字典存入总报告字典 (expression_report)
    expression_report[gene] = current_gene_report
    
    # ------------------------------------------------------------------
    
    # 当 for 循环结束后，expression_report 就会包含所有基因的完整结果。
    print(expression_report)
# Out:
# {'TP53': {'overall_mean': 50.8333, 'high_samples': {'sample2': 60, 'sample3': 55, 'sample6': 70}, 'low_samples': {'sample1': 50, 'sample4': 40, 'sample5': 30}, 'high_mean': 61.6667, 'low_mean': 40.0, 'shift': 21.6667}}
# {'TP53': {'overall_mean': 50.8333, 'high_samples': {'sample2': 60, 'sample3': 55, 'sample6': 70}, 'low_samples': {'sample1': 50, 'sample4': 40, 'sample5': 30}, 'high_mean': 61.6667, 'low_mean': 40.0, 'shift': 21.6667}, 'BRCA1': {'overall_mean': 4.6667, 'high_samples': {'sample1': 5, 'sample4': 6, 'sample6': 8}, 'low_samples': {'sample2': 3, 'sample3': 4, 'sample5': 2}, 'high_mean': 6.3333, 'low_mean': 3.0, 'shift': 3.3333}}
# ...

# %%
# Out:
# {'ENSG00000210082': {'overall_mean': 0.1667, 'high_samples': {'sample2': 1}, 'low_samples': {'sample1': 0, 'sample3': 0, 'sample4': 0, 'sample5': 0, 'sample6': 0}, 'high_mean': 1.0, 'low_mean': 0.0, 'shift': 1.0}}
