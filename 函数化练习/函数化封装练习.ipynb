# %%
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 70,
        "sample5": 75,
        "sample6": 65
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 3,
        "sample2": 4,
        "sample3": 5,
        "sample4": 6,
        "sample5": 7,
        "sample6": 8
    },
    "MIR21": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0,
        "sample4": 0,
        "sample5": 0,
        "sample6": 0
    },
    "EGFR": {
        "gene_name": "EGFR",
        "sample1": 100,
        "sample2": 110,
        "sample3": 105,
        "sample4": 130,
        "sample5": 125,
        "sample6": 140
    },
    "MYC": {
        "gene_name": "MYC",
        "sample1": 20,
        "sample2": 22,
        "sample3": 18,
        "sample4": 35,
        "sample5": 40,
        "sample6": 38
    },
    "GAPDH": {
        "gene_name": "GAPDH",
        "sample1": 10,
        "sample2": 11,
        "sample3": 9,
        "sample4": 10,
        "sample5": 11,
        "sample6": 10
    }
}

# %%
'''
🧩 函数化练习题 · 基于表达均值判断逻辑
🥇 Level 1：封装表达值提取函数
目标：写一个函数 get_expression_values(info)，输入一个基因的 info 字典，返回所有样本表达值（去掉 "gene_name"）

python
def get_expression_values(info):
    # TODO: 提取所有表达值，返回列表
✅ 输入示例：

python
info = {
    "gene_name": "TP53",
    "sample1": 50,
    "sample2": 60,
    "sample3": 55
}
✅ 输出：

python
[50, 60, 55]
'''

# %%
🧬 原始表达数据字典 expression_data
这是我们一直在用的基因表达数据结构：

python
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 70,
        "sample5": 75,
        "sample6": 65
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 3,
        "sample2": 4,
        "sample3": 5,
        "sample4": 6,
        "sample5": 7,
        "sample6": 8
    },
    "MIR21": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0,
        "sample4": 0,
        "sample5": 0,
        "sample6": 0
    },
    "EGFR": {
        "gene_name": "EGFR",
        "sample1": 100,
        "sample2": 110,
        "sample3": 105,
        "sample4": 130,
        "sample5": 125,
        "sample6": 140
    },
    "MYC": {
        "gene_name": "MYC",
        "sample1": 20,
        "sample2": 22,
        "sample3": 18,
        "sample4": 35,
        "sample5": 40,
        "sample6": 38
    },
    "GAPDH": {
        "gene_name": "GAPDH",
        "sample1": 10,
        "sample2": 11,
        "sample3": 9,
        "sample4": 10,
        "sample5": 11,
        "sample6": 10
    }
}
🧩 函数化练习题分级（Level 1 到 Level 5）
我们把原始的 for 循环逻辑拆成了几个函数化练习题，由浅入深：

🥇 Level 1：提取表达值函数
目标：写一个函数 get_expression_values(info) 功能：输入一个基因的 info 字典，返回所有样本表达值（去掉 "gene_name"）

python
def get_expression_values(info):
    ...
✅ 示例调用：

python
get_expression_values(expression_data["TP53"])  # 返回 [50, 60, 55, 70, 75, 65]
🥈 Level 2：计算均值函数
目标：写一个函数 calculate_mean(values) 功能：输入表达值列表，返回均值（保留两位小数）

python
def calculate_mean(values):
    ...
✅ 示例调用：

python
calculate_mean([50, 60, 55])  # 返回 55.0
🥉 Level 3：表达状态判断函数
目标：写一个函数 compare_to_global(gene_mean, global_mean) 功能：返回 "high"、"low" 或 "equal"

python
def compare_to_global(gene_mean, global_mean):
    ...
✅ 示例调用：

python
compare_to_global(55.0, 42.17)  # 返回 "high"


🪜 Level 4：组合调用函数（不封装主循环）
你可以在主程序中这样组合使用：

python
for gene, info in expression_data.items():
    values = get_expression_values(info)
    mean = calculate_mean(values)
    status = compare_to_global(mean, global_mean)



🏆 Level 5：封装整个流程为一个函数（进阶）
目标：写一个函数 compare_gene_expression(expression_data) 功能：返回每个基因的表达状态和均值信息

python
def compare_gene_expression(expression_data):
    ...
✅ 输出结构：

python
{
    "TP53": {
        "status": "high",
        "gene_mean": 62.5,
        "global_mean": 42.17
    },
    ...
}

# %%
expression_data = {
    "TP53": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55,
        "sample4": 70,
        "sample5": 75,
        "sample6": 65
    },
    "BRCA1": {
        "gene_name": "BRCA1",
        "sample1": 3,
        "sample2": 4,
        "sample3": 5,
        "sample4": 6,
        "sample5": 7,
        "sample6": 8
    },
    "MIR21": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0,
        "sample4": 0,
        "sample5": 0,
        "sample6": 0
    },
    "EGFR": {
        "gene_name": "EGFR",
        "sample1": 100,
        "sample2": 110,
        "sample3": 105,
        "sample4": 130,
        "sample5": 125,
        "sample6": 140
    },
    "MYC": {
        "gene_name": "MYC",
        "sample1": 20,
        "sample2": 22,
        "sample3": 18,
        "sample4": 35,
        "sample5": 40,
        "sample6": 38
    },
    "GAPDH": {
        "gene_name": "GAPDH",
        "sample1": 10,
        "sample2": 11,
        "sample3": 9,
        "sample4": 10,
        "sample5": 11,
        "sample6": 10
    }
}

def gene_info(gene):
    info = {}
    for gene_name,details in expression_data.items():
        gene == gene_name
        values = []
        for k,v in details.items():
            if k != "gene_name":
                values.append(v)
        info[gene] = values
    return info                
gene_info('TP53')
# Out:
# {'TP53': [10, 11, 9, 10, 11, 10]}

# %%
'''🧬 题目目标
你有一个表达矩阵 expression_data，每个基因对应多个样本的表达值。你还定义了两个分组：处理组（treatment） 和 对照组（control）。请完成以下任务：

用 for 循环计算每个基因在两个组中的平均表达值

输出每个组的样本及其表达值

判断处理组是否上调（处理组均值 > 对照组均值）

封装成函数并测试
'''

expression_data = {
    "TP53": {
        "sample_1": 60, "sample_2": 65, "sample_3": 40, "sample_4": 42
    },
    "EGFR": {
        "sample_1": 80, "sample_2": 85, "sample_3": 50, "sample_4": 55
    },
    "BRCA1": {
        "sample_1": 30, "sample_2": 28, "sample_3": 35, "sample_4": 38
    }
}

'''
group_info = {
   "TP53": {"treatment": {"sample_1":value, "sample_2":value},
    "control": {"sample_3":value, "sample_4":value},
    "treatment_mean":treat_mean,
    "control_mean":control_mean,
    "status":high},
...
}
'''
# Out:
# '\ngroup_info = {\n   "TP53": {"treatment": {"sample_1":value, "sample_2":value},\n    "control": {"sample_3":value, "sample_4":value},\n    "treatment_mean":treat_mean,\n    "control_mean":control_mean,\n    "status":high},\n...\n}\n'

# %%
expression_data = {
    "TP53": {
        "sample_1": 60, "sample_2": 65, "sample_3": 40, "sample_4": 42
    },
    "EGFR": {
        "sample_1": 80, "sample_2": 85, "sample_3": 50, "sample_4": 55
    },
    "BRCA1": {
        "sample_1": 30, "sample_2": 28, "sample_3": 35, "sample_4": 38
    }
}
group_info = {}
for gene,info in expression_data.items():
    gene_name = gene
    treatment = {}
    control = {}
    for sample,values in info.items():
        if sample in["sample_1" ,"sample_2"]:
            treatment[sample] = values
        if sample in ["sample_3","sample_4"]:
            control[sample] = values
    treatment_mean = sum(treatment.values())/len(treatment.values())
    control_mean = sum(control.values())/len(control.values())
   
    if treatment_mean >control_mean:
        status = "high"
    if treatment_mean < control_mean:
        status = "low"
    else:
        status = "no change"
            
    group_info[gene_name] = {"treatment":treatment,"control":control,"treatment_mean":treatment_mean,"control_mean":control_mean,"status":status}     
            
group_info["EGFR"]
# Out:
# {'treatment': {'sample_1': 80, 'sample_2': 85},
#  'control': {'sample_3': 50, 'sample_4': 55},
#  'treatment_mean': 82.5,
#  'control_mean': 52.5,
#  'status': 'no change'}

# %%
def analyze_expression_groups(expression_data, treatment_samples, control_samples,target_gene = None):
    group_info = {}

    for gene, info in expression_data.items():
        gene_name = gene
        treatment = {}
        control = {}
         # 如果指定了 target_gene，只处理它
        if target_gene and gene != target_gene:
            continue
        
        for sample, value in info.items():
            if sample in treatment_samples:
                treatment[sample] = value
            elif sample in control_samples:
                control[sample] = value

        treatment_mean = sum(treatment.values()) / len(treatment.values())
        control_mean = sum(control.values()) / len(control.values())

        if treatment_mean > control_mean:
            status = "high"
        elif treatment_mean < control_mean:
            status = "low"
        else:
            status = "no change"

        group_info[gene] = {
            "treatment": treatment,
            "control": control,
            "treatment_mean": round(treatment_mean, 2),
            "control_mean": round(control_mean, 2),
            "status": status
        }

    return group_info


# ✅ 在函数外定义分组
treatment_samples = ["sample_1", "sample_2"]
control_samples = ["sample_3", "sample_4"] 

analyze_expression_groups(expression_data, treatment_samples, control_samples,target_gene = 'BRCA1')
# Out:
# {'BRCA1': {'treatment': {'sample_1': 30, 'sample_2': 28},
#   'control': {'sample_3': 35, 'sample_4': 38},
#   'treatment_mean': 29.0,
#   'control_mean': 36.5,
#   'status': 'low'}}

# %%
dna_sequence = "ATGGCCATTGTAAATTAA" # 包含起始密码子(ATG)和终止密码子(TAA, TGA, TAG)

# 简化密码子表（只用于本题的演示和判断）

CODON_MAP = {

    "ATG": "Met", "GCC": "Ala", "ATT": "Ile", "GTA": "Val", "AAT": "Asn",

    "TAA": "STOP", "TGA": "STOP", "TAG": "STOP", "GCA": "Ala"

}

🎯 目标
给定一段 DNA 序列，你需要编写一个函数来模拟其翻译过程：将序列切割成三联体（密码子），然后统计每个氨基酸（或终止符）出现的次数
🧠 任务要求（分两部分）
第一部分：translate_and_count 函数封装
编写一个名为 translate_and_count(sequence, codon_map) 的函数，该函数需要完成以下工作：

切割序列： 从头开始（假设序列以起始密码子开始），将 sequence 每 3 个碱基切开，生成密码子。

翻译与计数：

遍历生成的密码子。

使用 codon_map 将密码子翻译成对应的氨基酸符号。

统计每个氨基酸符号（包括 "STOP"）出现的次数。

返回结果： 返回一个字典，键是氨基酸符号，值是出现次数。

第二部分：应用与结果输出
调用你封装的函数，并使用 for 循环（或列表推导式）对结果进行处理：

运行函数获取氨基酸计数结果。

过滤： 打印出所有出现次数 大于 1 的氨基酸及其计数。

好的，针对我们刚才完成的**“密码子翻译与统计”**练习，我使用的 for 循环伪代码思路主要集中在函数 translate_and_count 内部，步骤如下：

函数 translate_and_count(sequence, codon_map) 内部的伪代码思路
1. 初始化和准备
# 1. 初始化结果字典：用于存储氨基酸计数
amino_acid_counts = {}

# 2. 获取序列总长度
seq_length = length(sequence)
2. 主循环：序列切片和翻译
# 3. for 循环：从序列的起始（索引 0）开始，以 3 为步长进行遍历
#    循环变量 i 代表每个密码子的起始位置
for i 从 0 开始，到 seq_length 结束，每步增加 3:
    
    # 3.1 切割：获取当前位置 i 开始的 3 个碱基作为密码子
    codon = sequence[i 到 i+3]
    
    # 3.2 检查有效性：如果切割出来的 codon 长度不足 3 (即序列末尾的尾巴)，则跳过本轮循环
    if length(codon) < 3:
        继续 (continue)
        
    # 3.3 翻译：检查 codon 是否在 CODON_MAP 中
    if codon 存在于 codon_map 中:
        
        # 3.4 获取氨基酸名称
        amino_acid = codon_map[codon]
        
        # 3.5 计数：更新 amino_acid_counts 字典中的计数
        #      使用 get(key, 0) + 1 的方法实现：
        #      如果氨基酸存在，计数加 1；如果不存在，则初始化为 1
        amino_acid_counts[amino_acid] = amino_acid_counts.get(amino_acid, 0) + 1

    # else (可选): 否则，如果发现未知密码子，打印警告
    
# 4. 返回最终的计数结果字典
返回 amino_acid_counts
3. 外部应用循环（过滤结果）
# 5. 初始化过滤后的结果字典
filtered_results = {}

# 6. for 循环：遍历函数返回的 full_counts 字典的键值对 (氨基酸符号, 计数)
for aa_symbol, count in full_counts:
    
    # 7. 过滤条件：检查计数是否大于 1
    if count > 1:
        # 8. 将符合条件的键值对加入过滤后的字典
        filtered_results[aa_symbol] = count
        
# 9. 打印 filtered_results
