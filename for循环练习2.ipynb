# %%
'''🎯 任务：
请使用 for 循环，完成以下操作：

遍历 expression_data 中的每个基因。

对每个基因的样本表达量进行筛选，只保留表达量大于 50 的样本名。

构造一个新的字典 report，以 "gene_name" 为键，以符合条件的样本名列表为值。

如果某个基因没有任何样本表达量大于 50，则不包含在 report 中
'''

expression_data = {
    "ENSG00000141510": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55
    },
    "ENSG00000012048": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4
    },
    "ENSG00000139618": {
        "gene_name": "BRCA2",
        "sample1": 100,
        "sample2": 120,
        "sample3": 110
    },
    "ENSG00000210082": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0
    }
}

# %%
expression_data = { 
    "ENSG00000141510": {
        "gene_name": "TP53", 
        "sample1": 50, 
        "sample2": 60, 
        "sample3": 55 }, 
    "ENSG00000012048": 
    { "gene_name": "BRCA1",
      "sample1": 5, 
      "sample2": 3, 
      "sample3": 4 }, 
    "ENSG00000139618": {
        "gene_name": "BRCA2",
        "sample1": 100,
        "sample2": 120,
        "sample3": 110 }, 
    "ENSG00000210082": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1, 
        "sample3": 0 }
} 


'''
不如你先告诉下我，只想访问
"ENSG00000139618": { "gene_name": "BRCA2", "sample1": 100, "sample2": 120, "sample3": 110 },
里的gene_name和sample1的表达量，需要什么操作
'''


'''
可用操作
gene_name = expression_data["ENSG00000139618"]["gene_name"]
sample1_value = expression_data["ENSG00000139618"]["sample1"]
'''

# %%
expression_data = {
    "ENSG00000141510": {
        "gene_name": "TP53",
        "sample1": 50,
        "sample2": 60,
        "sample3": 55
    },
    "ENSG00000012048": {
        "gene_name": "BRCA1",
        "sample1": 5,
        "sample2": 3,
        "sample3": 4
    },
    "ENSG00000139618": {
        "gene_name": "BRCA2",
        "sample1": 100,
        "sample2": 120,
        "sample3": 110
    },
    "ENSG00000210082": {
        "gene_name": "MIR21",
        "sample1": 0,
        "sample2": 1,
        "sample3": 0
    }
}


report = {}

for gene_id, info in expression_data.items():
    gene_name = info["gene_name"]
    high_sample_values = {
    sample: value
    for sample, value in info.items()
    if sample != "gene_name" and value > 50
}
    # 只有在有高表达样本时才添加
    if high_sample_values:
        report[gene_name] = high_sample_values

# %%
'''
if sample != "gene_name" and value > 50这个操作是什么意思
是在一个 for 循环中，用来筛选表达量高于 50 的样本，同时排除掉不是样本的字段（比如 gene_name）。我们来逐步解释它的含义：

✅ 背景：你正在遍历一个嵌套字典
比如：

python
info = {
    "gene_name": "TP53",
    "sample1": 50,
    "sample2": 60,
    "sample3": 55
}
你用：

python
for sample, value in info.items():
会依次得到：

sample = "gene_name", value = "TP53"

sample = "sample1", value = 50

sample = "sample2", value = 60

sample = "sample3", value = 55

✅ 条件解释：
python
if sample != "gene_name" and value > 50
🔹 sample != "gene_name"
排除掉 "gene_name" 这个字段，因为它不是表达量，只是个标签。

🔹 value > 50
只保留表达量大于 50 的样本。

✅ 合起来的意思：
“如果当前键不是 gene_name，并且它的表达量大于 50，就把它当作高表达样本处理。

🧠 举个例子：
在 TP53 的表达数据中：

python
"sample1": 50   → 不满足 value > 50  
"sample2": 60   → 满足条件 ✅  
"sample3": 55   → 满足条件 ✅  
"gene_name": "TP53" → 被排除 ❌
最终你会得到：

python
["sample2", "sample3"]

'''
# Out:
# '\nif sample != "gene_name" and value > 50这个操作是什么意思\n是在一个 for 循环中，用来筛选表达量高于 50 的样本，同时排除掉不是样本的字段（比如 gene_name）。我们来逐步解释它的含义：\n\n✅ 背景：你正在遍历一个嵌套字典\n比如：\n\npython\ninfo = {\n    "gene_name": "TP53",\n    "sample1": 50,\n    "sample2": 60,\n    "sample3": 55\n}\n你用：\n\npython\nfor sample, value in info.items():\n会依次得到：\n\nsample = "gene_name", value = "TP53"\n\nsample = "sample1", value = 50\n\nsample = "sample2", value = 60\n\nsample = "sample3", value = 55\n\n✅ 条件解释：\npython\nif sample != "gene_name" and value > 50\n🔹 sample != "gene_name"\n排除掉 "gene_name" 这个字段，因为它不是表达量，只是个标签。\n\n🔹 value > 50\n只保留表达量大于 50 的样本。\n\n✅ 合起来的意思：\n“如果当前键不是 gene_name，并且它的表达量大于 50，就把它当作高表达样本处理。\n\n🧠 举个例子：\n在 TP53 的表达数据中：\n\npython\n"sample1": 50   → 不满足 value > 50  \n"sample2": 60   → 满足条件 ✅  \n"sample3": 55   → 满足条件 ✅  \n"gene_name": "TP53" → 被排除 ❌\n最终你会得到：\n\npython\n["sample2", "sample3"]\n\n'

# %%
# 🧠 整体思路：你要做的事情是
# 遍历每个基因的数据

# 提取基因名

# 筛选出表达量大于 50 的样本

# 把结果保存到一个新字典 report 中

# 🧩 拆解成小块写法
# 🔹 第一步：遍历字典

for gene_id, info in expression_data.items():
# gene_id 是基因编号，比如 "ENSG00000141510"

# info 是这个基因的表达数据，是一个嵌套字典

#🔹 第二步：取出基因名

gene_name = info["gene_name"]
# 从 info 中取出 "gene_name" 对应的值，比如 "TP53"

#🔹 第三步：筛选表达量 > 50 的样本

high_sample_values = {
    sample: value
    for sample, value in info.items()
    if sample != "gene_name" and value > 50
}
#这是字典推导式，等价于：


high_sample_values = {}
for sample, value in info.items():
    if sample != "gene_name" and value > 50:
        high_sample_values[sample] = value


#🔹 第四步：只添加有高表达样本的基因

if high_sample_values:
    report[gene_name] = high_sample_values
# 如果 high_sample_values 不是空字典，就把它加入 report
# Out:
#   Cell In[4], line 20
#     gene_name = info["gene_name"]
#     ^
# IndentationError: expected an indented block after 'for' statement on line 13

# %%
#✅ 最终结构你可以先写成这样：

report = {}

for gene_id, info in expression_data.items():
    gene_name = info["gene_name"]
    high_sample_values = {}

    for sample, value in info.items():
        if sample != "gene_name" and value > 50:
            high_sample_values[sample] = value

    if high_sample_values:
        report[gene_name] = high_sample_values

print(report)
# Out:
# {'TP53': {'sample2': 60, 'sample3': 55}, 'BRCA2': {'sample1': 100, 'sample2': 120, 'sample3': 110}}
